# %%
import math
math.sqrt(8)
# Out:
# 2.8284271247461903

# %% [markdown]
# ![matrix%201.png](attachment:matrix%201.png)

# %%
import numpy as np
a=np.matrix([[0,1],
            [-2,-3]])
b=np.matrix([[1,0],[3,-2]])
c=a+b
d=a-b
e=a*b#a.dot(b)
print(c,'\n',d,'\n')
print(e)
# Out:
# [[ 1  1]
#  [ 1 -5]]
#  [[-1  1]
#  [-5 -1]]
#
# [[  3  -2]
#  [-11   6]]

# %%
 print(a.dot(b))
# Out:
# [[  3  -2]
#  [-11   6]]

# %%
print(np.matmul(a,b))
# Out:
# [[  3  -2]
#  [-11   6]]

# %% [raw]
# in matrix multiplication the matrices dont need to be quadratic but the inner dimensions need to be same.
# the size of the resulting matrix will be the inner dimension
# [A]  *  [B] = [C]
# (n*m)  (m*p)   (n*p)

# %%
c=np.matrix([[1],
             [4],
             [3]])
c
# Out:
# matrix([[1],
#         [4],
#         [3]])

# %%
#to read the last element
M1 = [[8, 14, -6],
           [12,7,4], 
           [-11,3,21]]

matrix_length = len(M1)
#print(len(M1))

#To read the last element from each row.
for i in range(matrix_length):
    print(M1[i][-1])
# Out:
# -6
# 4
# 21

# %%
#matrix transpose
import numpy as np

M1 = np.array([[3, 6, 9], [5, -10, 15], [4,8,12]])
print("the original matrix is :\n",M1)
M2 = M1.transpose()

print("transpose of the matrix is:-\n",M2)
# Out:
# the original matrix is :
#  [[  3   6   9]
#  [  5 -10  15]
#  [  4   8  12]]
# transpose of the matrix is:-
#  [[  3   5   4]
#  [  6 -10   8]
#  [  9  15  12]]

# %% [raw]
# #slicing of the matrix
# Slicing will return you the elements from the matrix based on the start /end index given.
#
# The syntax for slicing is - [start:end]
# If the start index is not given, it is considered as 0. For example [:5], it means as [0:5].
# If the end is not passed, it will take as the length of the array.
# If the start/end has negative values, it will the slicing will be done from the end of the array.

# %%
import numpy as np

arr = np.array([2,4,6,8,10,12,14,16])
print(arr[3:6]) # will print the elements from 3 to 5
print(arr[:5]) # will print the elements from 0 to 4
print(arr[2:]) # will print the elements from 2 to length of the array.
print(arr[-5:-1]) # will print from the end i.e. -5 to -2
print(arr[:-1]) # will print from end i.e. 0 to -2
# Out:
# [ 8 10 12]
# [ 2  4  6  8 10]
# [ 6  8 10 12 14 16]
# [ 8 10 12 14]
# [ 2  4  6  8 10 12 14]

# %% [raw]
# he syntax will be M1[row_start:row_end, col_start:col_end]
#
# The first start/end will be for the row, i.e to select the rows of the matrix.
# The second start/end will be for the column, i.e to select the columns of the matrix.

# %%
M1 = np.array([[2, 4, 6, 8, 10], 
    [3, 6, 9, -12, -15],
    [4, 8, 12, 16, -20],
    [5, -10, 15, -20, 25]])
M1[1:3, 1:4]
# Out:
# array([[  6,   9, -12],
#        [  8,  12,  16]])

# %%
#to print all rows of the third column
import numpy as np
M1 = np.array([[2, 4, 6, 8, 10], 
    [3, 6, 9, -12, -15],
    [4, 8, 12, 16, -20],
    [5, -10, 15, -20, 25]])

print(M1[:,3]) # This will print all rows and the third column data.
# Out:
# [  8 -12  16 -20]

# %%
#to print first row and all columns
import numpy as np

M1 = np.array([[2, 4, 6, 8, 10], 
    [3, 6, 9, -12, -15],
    [4, 8, 12, 16, -20],
    [5, -10, 15, -20, 25]])
print(M1[:1,]) # This will print first row and all columns
# Out:
# [[ 2  4  6  8 10]]

# %%
#to print first 2 rows and two columns
import numpy as np

M1 = np.array([[2, 4, 6, 8, 10], 
    [3, 6, 9, -12, -15],
    [4, 8, 12, 16, -20],
    [5, -10, 15, -20, 25]])


print(M1[:2,:2])
# Out:
# [[2 4]
#  [3 6]]

# %%
#to print first 3 rows and two columns
import numpy as np

M1 = np.array([[2, 4, 6, 8, 10], 
    [3, 6, 9, -12, -15],
    [4, 8, 12, 16, -20],
    [5, -10, 15, -20, 25]])


print(M1[:2,:2])
# Out:
# [[2 4]
#  [3 6]]

# %%
#to print the rows of a matrix
import numpy as np
M1 = np.array([[3, 6, 9], [5, -10, 15], [4,8,12]])
print(M1[0])  #first row
print(M1[1]) # the second row
print(M1[-1]) # -1 will print the last row
# Out:
# [3 6 9]
# [  5 -10  15]
# [ 4  8 12]

# %%
#to print the columns of a matrix
import numpy as np
M1 = np.array([[2, 4, 6, 8, 10], 
    [3, 6, 9, -12, -15],
    [4, 8, 12, 16, -20],
    [5, -10, 15, -20, 25]])
print(M1[:,0]) # Will print the first Column
print(M1[:,3]) # Will  print the third Column
print(M1[:,-1]) # -1 will give you the last column
# Out:
# [2 3 4 5]
# [  8 -12  16 -20]
# [ 10 -15 -20  25]

# %% [markdown]
# #determinant of the matrix
# ![determinant.png](attachment:determinant.png)

# %%
# from numpy import *
import numpy as np
import numpy.linalg as la
a=np.matrix([[1,2],[3,4]])
print(la.det(a))
# Out:
# -2.0000000000000004

# %%
b=np.matrix([[-1,3,0],[2,1,-5],[1,4,-2]])
print(la.det(b))
# Out:
# -21.00000000000001

# %% [markdown]
# ## Inverse of a quadratic matrix

# %% [markdown]
# ![inverse%20matrix%20of%20quadratic.jpg](attachment:inverse%20matrix%20of%20quadratic.jpg)

# %%
a=np.array([[0,1],[-2,3]])
la.inv(a)
# Out:
# array([[ 1.5, -0.5],
#        [ 1. ,  0. ]])

# %%
eig_values,eig_vectors=la.eig(a)
eig_values
# Out:
# array([1., 2.])

# %%
eig_vectors
# Out:
# array([[-0.70710678, -0.4472136 ],
#        [-0.70710678, -0.89442719]])

# %% [markdown]
# ![7-1-eigenvalues-and-eigenvectors-n.jpg](attachment:7-1-eigenvalues-and-eigenvectors-n.jpg)

# %% [markdown]
# ![01.jpg](attachment:01.jpg)

# %% [markdown]
# ![02.jpg](attachment:02.jpg)

# %% [markdown]
# ![03.jpg](attachment:03.jpg)

# %% [markdown]
# ![04.jpg](attachment:04.jpg)

# %% [raw]
# # for suppose they have given the linear equations like this
# x1+2x2=5
# 3x1+4x2=6
# we want to put the equations in the general form:
#     ax=b
# this gives:
#     a[1 2]  b[5]   x=[x1]
#      [3 4]   [6]     [x2]
# the solution is given by
# x=(ainverse)*b
# #x=(a^-1*b)

# %%
import numpy as np 
import numpy.linalg as la
a=np.array([[1,2],[3,4]])
b=np.array([[5],[6]])
ainv=la.inv(a)
x=ainv*b
print(x)
# Out:
# [[-10.   5.]
#  [  9.  -3.]]
